# %% [markdown]
# # STRING FUNCTIONS
#  given below functions

# %%
name = 'ch.chandu'
age = '22'
course_logan = 'data engineer'

# %%
# concatination
print(name + age + course_logan)
# Out:
# ch.chandu22data engineer

# %%
# repitation
# name = 'ch.chandu'
print(name *10)
# Out:
# ch.chanduch.chanduch.chanduch.chanduch.chanduch.chanduch.chanduch.chanduch.chanduch.chandu

# %%
# length function
# name = 'ch.chandu'
print(len(name))
# Out:
# 9

# %%
# indexing
# name = 'ch.chandu'
print(name[-1])
# Out:
# u

# %%
# slicing
# name = 'ch.chandu'
print(name[0:3])
# Out:
# ch.

# %%
# str.lower()
# name = 'ch.chandu'
name.lower()
# Out:
# 'ch.chandu'

# %%
# str.upper()
# name = 'ch.chandu'
name.upper()
# Out:
# 'CH.CHANDU'

# %%
# str.strip()
x = '  data science '

# %%
x.strip()
# Out:
# 'data science'

# %%
# str.lstrip()
x.lstrip()
# Out:
# 'data science '

# %%
# str.rstrip()
x.rstrip()
# Out:
# '  data science'

# %%
# str.replace(old,new[,count])
x = "my name is chandu"
y = "iam playing cricket and volleyball"

# %%
# str.replace()
x.replace("chandu", "jaya krishna")
# Out:
# 'my name is jaya krishna'

# %%
# str.replace()
y = "iam playing cricket and volleyball"
y.replace("and","&")
# Out:
# 'iam playing cricket & volleyball'

# %%
# str.replace()
x = "my name is chandu"
x.replace(" ","_")
# Out:
# 'my_name_is_chandu'

# %%
# str.replace()
y = "iam playing cricket and volleyball"
y.replace(" ","")
# Out:
# 'iamplayingcricketandvolleyball'

# %%
# str.replace()          ####(no change)
y = "iam playing cricket and volleyball"
y.replace("tennis","cricket")
# Out:
# 'iam playing cricket and volleyball'
