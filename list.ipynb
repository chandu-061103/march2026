# %% [markdown]
# # LIST DATA TYPE

# %%
empty_list = []
print(type(empty_list))
# Out:
# <class 'list'>

# %%
course_list = ["Data science","Data engineering","Azure devops"]
students_count = [350,420,380,500,450]

# %%
print(course_list)
# Out:
# ['Data science', 'Data engineering', 'Azure devops']

# %%
print(students_count)
# Out:
# [350, 420, 380, 500, 450]

# %%
type(course_list)
# Out:
# list

# %% [markdown]
# INDEXING AND SLICING OF LIST

# %%
# first course
first_course = course_list[0]
last_course = course_list[-1]

# %%
first_course
# Out:
# 'Data science'

# %%
last_course
# Out:
# 'Azure devops'

# %%
students_count = [350, 420, 380, 500, 450]

first_count = students_count[0]
last_count = students_count[-1]

print('first count: ',first_count)
print('last count: ',last_count)
# Out:
# first count:  350
# last count:  450

# %%
## slicing on list

# [start: stop: step]

## get a slice of first 3 courses

course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]

first_3_course = course_list[0:3]
first_3_course
# Out:
# ['Data Science', 'Data Engineering', 'Azure DevOps']

# %%
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'Python Basics',
#  'SQL Fundamentals']

# %%
course_list[::3]
# Out:
# ['Data Science', 'Python Basics']

# %%
## get last two items

course_list[-2:]
# Out:
# ['Python Basics', 'SQL Fundamentals']

# %%
# indexing

course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
new_enrollments = [15, 20, 10]

list_with_all_types = [1,2.0,"string",[1,2,3,4]]

# %%
list_with_all_types
# Out:
# [1, 2.0, 'string', [1, 2, 3, 4]]

# %%
print(type(list_with_all_types))
print(type(list_with_all_types[3]))
list_with_all_types[3]
# Out:
# <class 'list'>
# <class 'list'>
# [1, 2, 3, 4]

# %%
list_with_all_types[3][2]
# Out:
# 3

# %%
new_nested_list =  [1,2,3, [4, 5, 6, [7, 8, 9]]]

# %%
new_nested_list[3][3][1]
# Out:
# 8

# %%
# changing elements from the list
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]

# %%
# changing first element "Data Science" to "Data Analyst"

course_list[0] = "Data analyst"

# %%
course_list
# Out:
# ['Data analyst', 'Data Engineering', 'Azure DevOps']

# %%
course_list[1] = "Data science"

# %%
course_list
# Out:
# ['Data analyst', 'Data science', 'Azure DevOps']

# %% [markdown]
# Adding elements to the existing list
#
# list.append(item)
# Adds a single item to the end of the list. Modifies the list in-place.
#
# in-place = changes the original list

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
new_enrollments = [15, 20, 10]

# %%
course_list.append("cloud computing")

# %%
course_list
# Out:
# ['Data Science', 'Data Engineering', 'Azure DevOps', 'cloud computing']

# %%
course_list.append("machine learning")

# %%
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'cloud computing',
#  'machine learning']

# %%
new_enrollments = [15, 20, 10]

new_enrollments.append(18)

# %%
new_enrollments
# Out:
# [15, 20, 10, 18]

# %%
## append a list a as single element  (nested list)

meta_list = [1,2]

# %%
meta_list
# Out:
# [1, 2]

# %%
meta_list.append([3,4])

# %%
meta_list
# Out:
# [1, 2, [3, 4]]

# %%
meta_list[2][1]
# Out:
# 4

# %%
## adding elemetnets to empty list

feedback_score = []

# %%
feedback_score.append(5)
feedback_score.append(4)
feedback_score.append(1)
feedback_score.append(7)
feedback_score.append("six")
feedback_score.append(7.0)

# %%
feedback_score
# Out:
# [5, 4, 1, 7, 'six', 7.0]

# %%
## append result of calculation

values = [10, 20]

# %%
values.append(values[0] + values[1])

# %%
values
# Out:
# [10, 20, 30]

# %%
values.append(values[1] + values[2])

# %%
values
# Out:
# [10, 20, 30, 50]

# %% [markdown]
# list.extend(iterable)
#
# Adds all items from an iterable (like another list, tuple, or string) to the end of the current list. Modifies the list in-place. Differs from append which adds the iterable as a single element

# %%
Data_science_courses = ["DS Intro", "Python for DS"]
data_eng_courses = ["DE Intro", "SQL for DE", "ADF"]
new_tools = ("Docker", "Kubernetes")

# %%
## adding DS course with DE coursee with append

Data_science_courses.append(data_eng_courses)

# %% [markdown]
# append and extend.. indexing. slicing.. replacing..
#
# to add elements
#
# # append(item)
# # extend(iterable) list. tuple
# # insert(index, item)
#
# list.insert(index, item)
#
# Inserts an item at a specific index. Existing items from that index onwards are shifted to the right. Modifies the list in-place..

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
priority_tasks = ["Deploy App", "Monitor Logs"]

# %%
# insert python basics at beginning
course_list.insert(0,"python basics")
course_list
# Out:
# ['python basics',
#  'python basics',
#  'Data Science',
#  'Data Engineering',
#  'Azure DevOps']

# %%
course_list.insert(2,"cloud entro")

# %%
course_list
# Out:
# ['python basics',
#  'python basics',
#  'cloud entro',
#  'Data Science',
#  'Data Engineering',
#  'Azure DevOps']

# %%
## adding high priority tast at the beginning
priority_tasks = ["Deploy App", "Monitor Logs"]
priority_tasks.insert(0, "Fix critical Bug")

# %%
priority_tasks
# Out:
# ['Fix critical Bug', 'Deploy App', 'Monitor Logs']

# %% [markdown]
# ### way to remove elements from the list
#
# ## list.remove(item)
#
# Removes the first occurrence of the specified item from the list. Raises a ValueError if the item is not found. Modifies the list in-place

# %%
course_list = ["Python Basics", "Data Science", "Cloud Intro", "Data Engineering", "Data Science"]
tools = ["Python", "SQL", "Git", "SQL"]

# %%
course_list.remove("Cloud Intro")

# %%
course_list
# Out:
# ['Python Basics', 'Data Science', 'Data Engineering', 'Data Science']

# %%
## removing data scinence

course_list.remove("Data Science")
course_list
# Out:
# ['Python Basics', 'Data Engineering', 'Data Science']

# %%
course_list.remove("Data Science")

# %%
course_list
# Out:
# ['Python Basics', 'Data Engineering']

# %%
tools = ["Python", "SQL", "Git", "SQL"]

# %%
tools.remove("SQL")

# %%
tools
# Out:
# ['Python', 'Git', 'SQL']

# %%
students_count = [350, 420, 380, 420]
students_count.remove(420)
students_count
# Out:
# [350, 380, 420]

# %% [markdown]
# ## list.pop([index])
#
# Explanation: Removes and returns the item at the given index. If index is omitted, it removes and returns the last item. Raises an IndexError if the list is empty or the index is out of range. Modifies the list in-place.

# %%
course_list = ["Python Basics", "Data Science", "Data Engineering"]
tasks = ["Review Code", "Update Docs", "Deploy"]

# %%
last_count = course_list.pop()

# %%
last_count
# Out:
# 'Data Engineering'

# %%
course_list
# Out:
# ['Python Basics', 'Data Science']

# %%
# remove first course 
first_course = course_list.pop(0)

# %%
first_course
# Out:
# 'Python Basics'

# %%
course_list
# Out:
# ['Data Science']

# %%
tasks = ["Review Code", "Update Docs", "Deploy"]

# %%
# removing last task
last_task = tasks.pop()
last_task
# Out:
# 'Deploy'

# %%
tasks
# Out:
# ['Review Code', 'Update Docs']

# %%
remove_docs = tasks.pop(1)

# %%
remove_docs
# Out:
# 'Update Docs'

# %%
tasks
# Out:
# ['Review Code']

# %%
tasks.append(last_task)

# %%
tasks
# Out:
# ['Review Code', 'Deploy']

# %%
tasks.append(first_course)

# %%
tasks
# Out:
# ['Review Code', 'Deploy', 'Python Basics']

# %% [markdown]
# Sorting the list
#
# ## list.sort(key=None, reverse=False)
#
# Explanation: Sorts the items of the list in-place.
#
# key: A function to be called on each element before making comparisons (e.g., key=str.lower for case-insensitive sort).
#
# reverse=True: Sorts in descending order. Items must be comparable (e.g., all numbers or all strings)

# %%
course_list = ["Data Engineering", "Azure DevOps", "Data Science", "Python Basics"]
student_counts = [350, 420, 380, 500, 450]
mixed_case_courses = ["azure DevOps", "Python basics", "Data science"]

# %%
## sort course list alphabetically (in-place)
course_list.sort()

# %%
course_list
# Out:
# ['Azure DevOps', 'Data Engineering', 'Data Science', 'Python Basics']

# %%
aplha_list = ["Z","A", "B", "Q", "C", "D", "H"]

# %%
aplha_list.sort()

# %%
aplha_list
# Out:
# ['A', 'B', 'C', 'D', 'H', 'Q', 'Z']

# %%
aplha_list.sort(reverse=True)

# %%
aplha_list
# Out:
# ['Z', 'Q', 'H', 'D', 'C', 'B', 'A']

# %%
## Boolean True, False,

## wrong way true, false

# %%
# sort mixed case courses case-insensitively

mixed_case_courses = ["azure DevOps", "Python basics", "Data science"]

# %%
mixed_case_courses.sort(key=str.lower)

# %%
mixed_case_courses
# Out:
# ['azure DevOps', 'Data science', 'Python basics']

# %%
mixed_case_courses.sort(key=str.upper)

# %%
mixed_case_courses
# Out:
# ['azure DevOps', 'Data science', 'Python basics']

# %%
# sort based on len
courses = ["SQL", "Python", "Azure DevOps", "Git"]

# %%
courses.sort(key=len)

# %%
courses
# Out:
# ['SQL', 'Git', 'Python', 'Azure DevOps']

# %% [markdown]
# ##### Assignment

# %%
# Task 1: Add Your Favorite Food
foods = ["pizza", "burger", "pasta"]
foods.append("biryani")

# %%
foods
# Out:
# ['pizza', 'burger', 'pasta', 'biryani']

# %%
# Task 2: Add Multiple Items
colors = ["red", "blue"]
colors.insert(1,"yellow"),colors.insert(2,"green")
# Out:
# (None, None)

# %%
colors
# Out:
# ['red', 'yellow', 'green', 'blue']

# %%
# Task 3: Insert at Specific Position
numbers = [1, 2, 4, 5]
numbers.insert(2,3)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
# Task 4: Remove an Item
fruits = ["apple", "banana", "mango", "grapes"]

# %%
fruits.remove("mango")

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
# Task 5: Remove Last Item
items = ["pen", "book", "eraser"]
items.pop()
# Out:
# 'eraser'

# %%
items
# Out:
# ['pen', 'book']

# %%
# Task 6: Find Index
animals = ["cat", "dog", "lion", "tiger"]
animals.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 3
#       1 # Task 6: Find Index
#       2 animals = ["cat", "dog", "lion", "tiger"]
# ----> 3 animals.index(0)
#
# ValueError: 0 is not in list

# %%
## Task 7: Count Occurrences
nums = [1, 2, 2, 3, 2, 4]
nums.count(2)
# Out:
# 3

# %%
## Task 8: Sort the List
marks = [85, 45, 90, 60]
marks.sort()

# %%
marks
# Out:
# [45, 60, 85, 90]

# %%
## Task 9: Reverse the List
letters = ["a", "b", "c", "d"]
letters.sort(reverse=True)

# %%
letters
# Out:
# ['d', 'c', 'b', 'a']

# %%
# Task 11: Clear the List
data = [1, 2, 3, 4]
data.clear()

# %%
data
# Out:
# []

# %%
# Task 12: Extend a List
list1 = [1, 2]
list2 = [3, 4]
list1.append([3,4])

# %%
list1
# Out:
# [1, 2, [3, 4]]
